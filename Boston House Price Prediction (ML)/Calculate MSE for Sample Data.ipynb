# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
#Generate n evenly spaced values from zero radians to 2 PI radians
n=200
x=np.linspace(0,2*np.pi,n)
sine_values=np.sin(x)
plt.plot(x,sine_values)

# %%
noise=0.5
noisy_sine_values=sine_values+np.random.uniform(-noise,noise,n)
noisy_sine_values
# Out:
# array([ 0.01270495,  0.10920547, -0.15001088,  0.50680499,  0.48611421,
#         0.3694568 ,  0.12111615,  0.27879884,  0.53749006,  0.72844131,
#         0.59965215, -0.026976  , -0.07900052,  0.21220859,  0.71707651,
#         0.86088041,  0.6388353 ,  0.19130659,  0.43800876,  0.39331672,
#         0.51009799,  0.72301363,  0.4788951 ,  0.70092659,  1.17257652,
#         0.30539171,  0.62422393,  1.14619417,  1.15585117,  0.84650211,
#         0.55442291,  1.23195483,  0.37878341,  0.57255434,  0.76447634,
#         0.54605195,  0.59423311,  0.64019241,  0.53475976,  0.54332465,
#         0.99743735,  0.6058982 ,  1.11112637,  1.35202473,  0.74368713,
#         0.86598827,  1.02729378,  1.46352434,  0.74374127,  0.86048668,
#         0.52410862,  0.57578137,  1.32926211,  1.4098788 ,  1.33090185,
#         0.57127102,  0.95848959,  0.7398298 ,  0.94224728,  0.97796807,
#         0.64992353,  0.85633074,  0.54235023,  1.09471856,  0.47073185,
#         0.77173644,  0.63502785,  0.89047361,  0.86988095,  0.56689539,
#         0.48419862,  0.30199915,  0.8870299 ,  0.5565038 ,  1.10322022,
#         0.39265304,  1.02801475,  0.44086815,  0.81904904,  0.74820805,
#         0.42438558,  1.00649555,  0.98047298,  0.3961009 , -0.01343553,
#         0.79318477,  0.28496962,  0.76760543,  0.30608375,  0.54918205,
#        -0.04470794,  0.5378287 ,  0.61194516, -0.11898168,  0.09241118,
#        -0.19199675,  0.09033596, -0.20933603, -0.09765696, -0.23307286,
#         0.26640763,  0.15522868,  0.14701075,  0.12003151, -0.03195287,
#        -0.15440048, -0.02017887, -0.36424767, -0.19788675, -0.45492349,
#        -0.04433435,  0.06909114, -0.31101935, -0.5759976 ,  0.0033872 ,
#        -0.76351591, -0.71513162, -0.12526538, -0.21458062, -0.24570234,
#        -1.09504215, -1.06361134, -0.21444587, -0.30861616, -0.94443684,
#        -0.47180284, -0.85939686, -0.98963024, -0.64554881, -0.59622168,
#        -0.3725887 , -1.22087892, -0.98582742, -0.58812684, -0.9489631 ,
#        -1.38673315, -0.71850615, -0.45886913, -0.82936506, -1.37805472,
#        -0.92518216, -1.24995345, -0.92903242, -0.94604288, -0.70366249,
#        -1.30744875, -0.83272329, -1.4520707 , -0.81777806, -0.64816687,
#        -1.18526931, -0.51784814, -1.46796716, -1.46328106, -0.88665314,
#        -0.51384823, -0.65822237, -1.25042172, -0.62671933, -1.36686215,
#        -0.88164048, -0.80394679, -1.08486664, -0.47603579, -0.89044672,
#        -1.32198328, -1.10424219, -1.10117401, -1.09101875, -0.47044461,
#        -0.93779459, -1.10625427, -1.02195582, -0.82244447, -0.71448589,
#        -0.98247177, -0.74831017, -0.68206731, -0.38688196, -0.12756781,
#        -0.79660141, -0.16348981, -0.90410344, -0.27983278, -0.83560107,
#        -0.17664731,  0.01435856, -0.4071487 , -0.17967239, -0.41455479,
#        -0.30874608, -0.73600956, -0.00644539, -0.15126678, -0.35009234,
#        -0.43819034, -0.15985381, -0.36190681,  0.34363435, -0.18717888])

# %%
plt.plot(x,noisy_sine_values,color='r')
plt.plot(x,sine_values,color='y')

# %%
#calculate MSE using equation
error_value=(1/n)*sum(np.power(sine_values-noisy_sine_values,2))
error_value
# Out:
# 0.08346414931766286

# %%
mse=mean_squared_error(sine_values,noisy_sine_values)
mse
# Out:
# 0.08346414931766283
